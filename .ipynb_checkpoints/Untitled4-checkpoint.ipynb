# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect(':memory:')

pd.DataFrame({
    'id':         [1, 2, 3, 4, 5, 6],
    'name':       ['a', 'b', 'c', 'd', 'e', 'f'],
    'department': ['engineering', 'marketing', 'engineering', 'hr', 'marketing', 'engineering'],
    'salary':     [95000, 45000, 50000, 79000, 44000, 90000],
    'age':        [45, 22, 27, 29, 19, 31]
}).to_sql('employees', conn, index = False)
print('ready')
# Out:
# ready

# %%
result = pd.read_sql_query("""
    SELECT *
    FROM (
        SELECT name, department, salary,
            ROW_NUMBER() OVER (PARTITION BY department ORDER BY salary DESC) as rn
        FROM employees
        ) ranked
        WHERE rn = 1
""", conn)
print(result)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/4.5.1/libexec/lib/python3.14/site-packages/pandas/io/sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: near "FROM": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result = pd.read_sql_query("""
#       2     FROM (
#       3         SELECT name, department, salary,
#       4             ROW_NUMBER() OVER (PARTITION BY department ORDER BY salary DESC) as rn
#       5         FROM employees
#       6         ) ranked
#       7         WHERE rn = 1
#       8 """, conn)
#       9 print(result)
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.1/libexec/lib/python3.14/site-packages/pandas/io/sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.1/libexec/lib/python3.14/site-packages/pandas/io/sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.1/libexec/lib/python3.14/site-packages/pandas/io/sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
#     FROM (
#         SELECT name, department, salary,
#             ROW_NUMBER() OVER (PARTITION BY department ORDER BY salary DESC) as rn
#         FROM employees
#         ) ranked
#         WHERE rn = 1
# ': near "FROM": syntax error
